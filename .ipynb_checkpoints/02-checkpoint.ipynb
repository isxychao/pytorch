# %% [markdown]
# # PyTorch练习1

# %%
#请输出你的姓名
print('赵旭阳')
# Out:
# 赵旭阳

# %% [markdown]
# ## 使用tensor与自动求导编写并训练一个线性回归器

# %%
import torch
print(torch.__version__)
# Out:
# 1.9.0

# %%
#生成训练数据
x = torch.rand(30,2)*10 - 5 
w0 = torch.tensor([2,-1],dtype = torch.float32)
b0 = torch.tensor([1.7],dtype = torch.float32)
y = torch.matmul(x,w0) + b0 + torch.randn(30)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


xarr = x.numpy()
yarr = y.numpy()
fig = plt.figure(0, figsize=(4, 3))
plt.clf()
ax = Axes3D(fig, elev=45, azim=100)
ax.scatter(x[:, 0], x[:, 1], y)
plt.show()
# Out:
# <ipython-input-5-ed774df43bf9>:9: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig, elev=45, azim=100)

# %%
def linearReg(x, w, b):
    y = x @ w.T + b
    return y

def lossFn(y, y_hat):
    squared_errors = (y - y_hat) ** 2
    loss = squared_errors.mean()
    return loss


import torch.optim as optim
def trainModel(x, y, w, b, epochs, lr=0.1):
    optimizer = optim.SGD([w,b], lr=lr)
    
    for epoch in range(1, epochs + 1):
        optimizer.zero_grad()
        y_pred = linearReg(x, w, b)
        loss = lossFn(y_pred, y)
        loss.backward()
        optimizer.step()
        print('Epoch = {0}, Loss = {1}, w = {2}, b = {3}'.format(epoch, loss.detach().numpy(), w.detach().numpy(),b.detach().numpy()))
    return w,b


w = torch.tensor([0.0, 0.0], requires_grad=True)
b = torch.tensor([0.0], requires_grad=True)
w,b = trainModel(x, y, w, b, epochs=10, lr=0.1)
# Out:
# Epoch = 1, Loss = 37.78663635253906, w = [ 2.7750373 -1.5731882], b = [0.18825617]
# Epoch = 2, Loss = 12.371932029724121, w = [ 1.6117749  -0.31866443], b = [0.57840383]
# Epoch = 3, Loss = 5.829015731811523, w = [ 2.192063  -1.2355976], b = [0.71860886]
# Epoch = 4, Loss = 3.2848806381225586, w = [ 1.8675286 -0.6546809], b = [0.9515104]
# Epoch = 5, Loss = 2.1538310050964355, w = [ 2.0643246 -1.0552803], b = [1.0621238]
# Epoch = 6, Loss = 1.6191165447235107, w = [ 1.9427401  -0.81543356], b = [1.202331]
# Epoch = 7, Loss = 1.352312684059143, w = [ 2.0205722 -0.98437  ], b = [1.2834647]
# Epoch = 8, Loss = 1.211618423461914, w = [ 1.971682  -0.8880974], b = [1.370087]
# Epoch = 9, Loss = 1.1333709955215454, w = [ 2.0035052 -0.9595655], b = [1.4269272]
# Epoch = 10, Loss = 1.0877835750579834, w = [ 1.9836075 -0.9216991], b = [1.481566]
